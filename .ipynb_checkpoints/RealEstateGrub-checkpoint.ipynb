# %% [markdown]
# ## About dataset
#
# ### Long-term rent (per-month payments) appartments in Lviv
#
# Dataset was generated from web-site https://dom.ria.com/uk
# for Lviv, UA (real estate rent, timeframe - 1 month)

# %% [markdown]
# ## In this project
#
# we will learn how to do
#
# * Data mining
# * Data cleaning
# * Aggregations and Visualization
# * Uncovering insights
# * Build take-away's

# %% [markdown]
# ### Some definitions
#
# <table>
#     <tr><td><b># of rooms</b></td><td><b>name</b></td></tr>
#     <tr><td>1</td><td>Studio</td></tr>
#     <tr><td>2</td><td>One Bedroom Apartments</td></tr>
#     <tr><td>3</td><td>Two Bedroom Apartments</td></tr>
#     <tr><td>4</td><td>Tree Bedroom Apartments</td></tr>
#     <tr><td>5</td><td>Four Bedroom Apartments</td></tr>
#     <tr><td>6</td><td>Five Bedroom Apartments</td></tr>
# </table>

# %% [markdown]
# ### Data mining

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.25.8)

# %%
import json
import numpy as np
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
print(folium.__version__)
# Out:
# 0.11.0

# %% [markdown]
# let's read dataset from the file. <br>
# to generate dataset please use this PostMan collection <br>
# https://www.getpostman.com/collections/8b0e3866ebb35327537c

# %%
with open("data_01.json","r", errors='ignore') as json_file:
    data_01 = json.load(json_file)
    
with open("data_02.json","r", errors='ignore') as json_file:
    data_02 = json.load(json_file)
    
with open("data_03.json","r", errors='ignore') as json_file:
    data_03 = json.load(json_file)

# %% [markdown]
# let's check if data exists in json file

# %%
print(len(data_01["items"]))
print(len(data_02["items"]))
print(len(data_03["items"]))
# Out:
# 1000
# 1000
# 256

# %% [markdown]
# Ok, now we are going to defune csv structure and load data from json

# %%
def write_header_to_file():
    f = open("dump.csv", "w")
    f.write(
        "id" + "," +
        "realty_id" + "," +
        "total_square_meters" + "," +
        "rooms_count" + "," +
        "floors_count" + "," +
        "floor" + "," +
        "price" + "," +
        "price_item" + "," +
        "district_id" + "," +
        "is_commercial" + "," +
        "agency_id" + "," +
        "deleted_by" + "," +
        "delete_reason" + "," +
        "longitude" + "," +
        "latitude" + "," +
        "price_usd" + "," +
        "price_eur" + "," +
        "price_uah" + "\n"
    )
    f.close()

def write_to_file(data):
    f = open("dump.csv", "a")
    for item in data["items"]:
        f.write(
            str(item.get("_id", "")) + "," +
            str(item.get("realty_id", "")) + "," +
            str(item.get("total_square_meters", "")) + "," +
            str(item.get("rooms_count", "")) + "," +
            str(item.get("floors_count", "")) + "," +
            str(item.get("floor", "")) + "," +
            str(item.get("price", "")) + "," +
            str(item.get("price_item", "")) + "," +
            str(item.get("district_id", "")) + "," +
            str(item.get("is_commercial", "")) + "," +
            str(item.get("agency_id", "")) + "," +
            str(item.get("deleted_by", "")) + "," +
            str(item.get("delete_reason", "")) + "," +
            str(item.get("longitude", "")) + "," +
            str(item.get("latitude", "")) + "," +
            str(item.get("priceArr", "").get("1", "")) + "," +
            str(item.get("priceArr", "").get("2", "")) + "," +
            str(item.get("priceArr", "").get("3", "")) + "\n"
        )
    f.close()

write_header_to_file()
write_to_file(data_01)
write_to_file(data_02)
write_to_file(data_03)
    
print("done..")
# Out:
# done..

# %% [markdown]
# ### Data cleaning

# %%
df = pd.read_csv("dump.csv")
df.head()
# Out:
#                 id  realty_id  total_square_meters  rooms_count  floors_count  \
# 0  realty-17177573   17177573                 50.0            1            10
# 1  realty-17119995   17119995                 50.0            1             3
# 2  realty-17200804   17200804                 34.0            1             2
# 3  realty-17177609   17177609                 65.0            2            10
# 4  realty-16949099   16949099                 60.0            2             4
#
#    floor  price  price_item  district_id  is_commercial  agency_id deleted_by  \
# 0      6    450         9.0        15090              1    23844.0        NaN
# 1      2    400         8.0        15089              1    23844.0        NaN
# 2      2   3900       115.0        15090              0        NaN        NaN
# 3      6    550         8.0        15090              1    23844.0        NaN
# 4      3   8000       133.0        15088              0        NaN       cron
#
#    delete_reason  longitude   latitude price_usd price_eur price_uah
# 0            NaN  24.050093  49.818576       450       400    12 262
# 1            NaN  24.056087  49.838916       400       355    10 899
# 2            NaN  24.026230  49.816677       143       127     3 900
# 3            NaN  24.050093  49.818576       550       489    14 986
# 4            1.0  24.004730  49.838692       294       261     8 000

# %%
# df.query('rooms_count == 2').sort_values(by='price_usd', ascending=False).head(10)
# df.query('total_square_meters == 3142.0')

# df = df.drop(df[df.total_square_meters == 3142.0].index)
# df = df.drop(df[df.price_usd == 8000.0].index)

# df['id'].count()
# Out:
# 2254

# %% [markdown]
# Some data cleaning and polishing

# %%
df["price_usd"] = df["price_usd"].astype(str).str.replace(" ","")
df["price_eur"] = df["price_eur"].astype(str).str.replace(" ","")
df["price_uah"] = df["price_uah"].astype(str).str.replace(" ","")

df["price_usd"] = pd.to_numeric(df["price_usd"], errors='ignore')
df["price_eur"] = pd.to_numeric(df["price_eur"], errors='ignore')
df["price_uah"] = pd.to_numeric(df["price_uah"], errors='ignore')

df["price_usd"] = df["price_usd"].astype(float)
df["price_eur"] = df["price_eur"].astype(float)
df["price_uah"] = df["price_uah"].astype(float)

df.head()
# Out:
#                 id  realty_id  total_square_meters  rooms_count  floors_count  \
# 0  realty-17177573   17177573                 50.0            1            10
# 1  realty-17119995   17119995                 50.0            1             3
# 2  realty-17200804   17200804                 34.0            1             2
# 3  realty-17177609   17177609                 65.0            2            10
# 4  realty-16949099   16949099                 60.0            2             4
#
#    floor  price  price_item  district_id  is_commercial  agency_id deleted_by  \
# 0      6    450         9.0        15090              1    23844.0        NaN
# 1      2    400         8.0        15089              1    23844.0        NaN
# 2      2   3900       115.0        15090              0        NaN        NaN
# 3      6    550         8.0        15090              1    23844.0        NaN
# 4      3   8000       133.0        15088              0        NaN       cron
#
#    delete_reason  longitude   latitude  price_usd  price_eur  price_uah
# 0            NaN  24.050093  49.818576      450.0      400.0    12262.0
# 1            NaN  24.056087  49.838916      400.0      355.0    10899.0
# 2            NaN  24.026230  49.816677      143.0      127.0     3900.0
# 3            NaN  24.050093  49.818576      550.0      489.0    14986.0
# 4            1.0  24.004730  49.838692      294.0      261.0     8000.0

# %% [markdown]
# do some more diligence

# %%
df['deleted_by'].unique()
# Out:
# array([nan, 'cron', 'admin', 'user'], dtype=object)

# %%
df['deleted'] = [True if s in ['nan', 'cron', 'admin', 'user'] else False for s in df['deleted_by']]
df.head()
# Out:
#                 id  realty_id  total_square_meters  rooms_count  floors_count  \
# 0  realty-17177573   17177573                 50.0            1            10
# 1  realty-17119995   17119995                 50.0            1             3
# 2  realty-17200804   17200804                 34.0            1             2
# 3  realty-17177609   17177609                 65.0            2            10
# 4  realty-16949099   16949099                 60.0            2             4
#
#    floor  price  price_item  district_id  is_commercial  agency_id deleted_by  \
# 0      6    450         9.0        15090              1    23844.0        NaN
# 1      2    400         8.0        15089              1    23844.0        NaN
# 2      2   3900       115.0        15090              0        NaN        NaN
# 3      6    550         8.0        15090              1    23844.0        NaN
# 4      3   8000       133.0        15088              0        NaN       cron
#
#    delete_reason  longitude   latitude  price_usd  price_eur  price_uah  \
# 0            NaN  24.050093  49.818576      450.0      400.0    12262.0
# 1            NaN  24.056087  49.838916      400.0      355.0    10899.0
# 2            NaN  24.026230  49.816677      143.0      127.0     3900.0
# 3            NaN  24.050093  49.818576      550.0      489.0    14986.0
# 4            1.0  24.004730  49.838692      294.0      261.0     8000.0
#
#    deleted
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True

# %%
df.drop(['price','price_item','deleted_by','delete_reason'], axis=1, inplace=True)
df.head()
# Out:
#                 id  realty_id  total_square_meters  rooms_count  floors_count  \
# 0  realty-17177573   17177573                 50.0            1            10
# 1  realty-17119995   17119995                 50.0            1             3
# 2  realty-17200804   17200804                 34.0            1             2
# 3  realty-17177609   17177609                 65.0            2            10
# 4  realty-16949099   16949099                 60.0            2             4
#
#    floor  district_id  is_commercial  agency_id  longitude   latitude  \
# 0      6        15090              1    23844.0  24.050093  49.818576
# 1      2        15089              1    23844.0  24.056087  49.838916
# 2      2        15090              0        NaN  24.026230  49.816677
# 3      6        15090              1    23844.0  24.050093  49.818576
# 4      3        15088              0        NaN  24.004730  49.838692
#
#    price_usd  price_eur  price_uah  deleted
# 0      450.0      400.0    12262.0    False
# 1      400.0      355.0    10899.0    False
# 2      143.0      127.0     3900.0    False
# 3      550.0      489.0    14986.0    False
# 4      294.0      261.0     8000.0     True

# %%
df.columns
# Out:
# Index(['id', 'realty_id', 'total_square_meters', 'rooms_count', 'floors_count',
#        'floor', 'district_id', 'is_commercial', 'agency_id', 'longitude',
#        'latitude', 'price_usd', 'price_eur', 'price_uah', 'deleted'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                      object
# realty_id                int64
# total_square_meters    float64
# rooms_count              int64
# floors_count             int64
# floor                    int64
# district_id              int64
# is_commercial            int64
# agency_id              float64
# longitude              float64
# latitude               float64
# price_usd              float64
# price_eur              float64
# price_uah              float64
# deleted                   bool
# dtype: object

# %%
df.count()
# Out:
# id                     2255
# realty_id              2255
# total_square_meters    2255
# rooms_count            2255
# floors_count           2255
# floor                  2255
# district_id            2255
# is_commercial          2255
# agency_id              1955
# longitude               282
# latitude                282
# price_usd              2254
# price_eur              2254
# price_uah              2254
# deleted                2255
# dtype: int64

# %%
df.describe()
# Out:
#           realty_id  total_square_meters  rooms_count  floors_count  \
# count  2.255000e+03          2255.000000  2255.000000   2255.000000
# mean   1.567750e+07            55.279113     1.814191      6.735698
# std    1.564336e+06            22.162694     0.801824      3.581382
# min    1.101993e+07            18.000000     1.000000      1.000000
# 25%    1.575244e+07            41.000000     1.000000      4.000000
# 50%    1.582710e+07            50.000000     2.000000      6.000000
# 75%    1.696504e+07            65.000000     2.000000      9.000000
# max    1.737788e+07           230.000000     6.000000     50.000000
#
#              floor   district_id  is_commercial     agency_id   longitude  \
# count  2255.000000   2255.000000    2255.000000   1955.000000  282.000000
# mean      3.828381  14734.458980       0.867849  26256.621483   24.023056
# std       2.488178   2384.110408       0.338730   2189.895887    0.044556
# min       0.000000      0.000000       0.000000      0.000000   23.928544
# 25%       2.000000  15087.000000       1.000000  24288.000000   24.004828
# 50%       3.000000  15090.000000       1.000000  27930.000000   24.023244
# 75%       5.000000  15091.000000       1.000000  27930.000000   24.032995
# max      16.000000  17787.000000       1.000000  30084.000000   24.547414
#
#          latitude    price_usd    price_eur      price_uah
# count  282.000000  2254.000000  2254.000000    2254.000000
# mean    49.835508   349.939663   310.751996    9533.618900
# std      0.043844   231.621498   205.767782    6311.713431
# min     49.617626   110.000000    98.000000    3000.000000
# 25%     49.821188   268.000000   238.000000    7300.000000
# 50%     49.838360   301.000000   267.000000    8200.000000
# 75%     49.847089   367.000000   326.000000   10000.000000
# max     50.373606  8000.000000  7106.000000  217984.000000

# %% [markdown]
# ### Dataset legend
# <table>
#     <tr><td><b>id</b></td><td>unique id, natural key</td></tr>
#     <tr><td><b>realty_id</b></td><td>realty identifier</td></tr>
#     <tr><td><b>total_square_meters</b></td><td>entire area in srt meters</td></tr>
#     <tr><td><b>rooms_count</b></td><td>number of rooms, including kitchen and living room (not a bed rooms only)</td></tr>
#     <tr><td><b>floors_count</b></td><td>number of floors</td></tr>
#     <tr><td><b>floor</b></td><td>current floor, starting from 1st as a ground floor</td></tr>
#     <tr><td><b>district_id</b></td><td>unique district id (will be mapped later on)</td></tr>
#     <tr><td><b>is_commercial</b></td><td>does this for commertial use?</td></tr>
#     <tr><td><b>agency_id</b></td><td>uniqie agency id (will be mapped later on)</td></tr>
#     <tr><td><b>longitude</b></td><td>geo longitude</td></tr>
#     <tr><td><b>latitude</b></td><td>get latitude</td></tr>
#     <tr><td><b>price_usd</b></td><td>price in usd, per month</td></tr>
#     <tr><td><b>price_eur</b></td><td>price in eur, per month</td></tr>
#     <tr><td><b>price_uah</b></td><td>price in uah, per month</td></tr>
#     <tr><td><b>deleted</b></td><td>active or not?</td></tr>
# </table>

# %% [markdown]
# Ok, our dataset is ready

# %% [markdown]
# ### Aggregations and Visualization

# %% [markdown]
# #### Appartment Size (# of Rooms) distribution
# <hr>

# %%
grouped_rooms_count = df[['rooms_count', 'id']].groupby("rooms_count").count()
grouped_rooms_count
# Out:
#               id
# rooms_count
# 1            884
# 2            979
# 3            334
# 4             44
# 5             13
# 6              1

# %%
plot = grouped_rooms_count.plot.bar(y='id', figsize=(15, 5))

# %%
grouped_price_usd = df[['rooms_count', 'price_usd']].groupby("rooms_count").mean()
grouped_price_usd = grouped_price_usd.apply(lambda x: round(x, 2))
grouped_price_usd
# Out:
#              price_usd
# rooms_count
# 1               289.57
# 2               336.82
# 3               442.05
# 4               783.64
# 5               925.85
# 6              1500.00

# %%
plot = grouped_price_usd.plot.bar(y='price_usd', figsize=(15, 5))

# %% [markdown]
# #### Average price per appatment size distribution
# <hr>

# %%
grouped_price_usd = df[['rooms_count', 'price_usd']].groupby("rooms_count").mean()
grouped_price_usd['price_usd'] = round(grouped_price_usd['price_usd'], 2)

grouped_price_eur = df[['rooms_count', 'price_eur']].groupby("rooms_count").mean()
grouped_price_eur['price_eur'] = round(grouped_price_eur['price_eur'], 2)

grouped_price_uah = df[['rooms_count', 'price_uah']].groupby("rooms_count").mean()
grouped_price_uah['price_uah'] = round(grouped_price_uah['price_uah'], 2)

frames = [grouped_price_usd, grouped_price_eur, grouped_price_uah]
aggregate = pd.concat(frames, axis=1)

# rename columns after concat
aggregate.columns = ['usd', 'eur', 'uah'] 
data = aggregate.apply(lambda x: round(x, 2))
data
# Out:
#                  usd      eur       uah
# rooms_count
# 1             289.57   257.11   7888.24
# 2             336.82   299.10   9176.10
# 3             442.05   392.62  12044.76
# 4             783.64   696.09  21351.20
# 5             925.85   822.38  25228.38
# 6            1500.00  1332.00  40872.00

# %% [markdown]
# #### Commertial VS Private distribution
# <hr>

# %%
grouped_is_commercial = df[['is_commercial', 'id']].groupby("is_commercial").count()
grouped_is_commercial
# Out:
#                  id
# is_commercial
# 0               298
# 1              1956

# %%
plot = grouped_is_commercial.plot.pie(x='is_commercial', y='id', figsize=(5, 5))

# %% [markdown]
# #### Active VS Not Active
# <hr>

# %%
grouped_is_commercial = df[['id', 'deleted']].groupby("deleted").count()
grouped_is_commercial
# Out:
#            id
# deleted
# False     515
# True     1739

# %% [markdown]
# #### Agency weight distribution
# <hr>

# %%
grouped_agency_id = df[['agency_id', 'id']].groupby("agency_id").count()
grouped_agency_id.sort_values(by='id', ascending=False)
# Out:
#             id
# agency_id
# 27930.0    875
# 24288.0    691
# 28200.0    113
# 24021.0     83
# 29684.0     27
# 24804.0     20
# 23844.0     19
# 23348.0     18
# 29645.0     12
# 18785.0     10
# 22935.0     10
# 22257.0      9
# 27978.0      8
# 26457.0      8
# 25601.0      6
# 29930.0      6
# 27556.0      4
# 30084.0      4
# 24879.0      4
# 23925.0      4
# 25600.0      3
# 28976.0      3
# 29679.0      3
# 26820.0      2
# 29648.0      2
# 21563.0      2
# 0.0          2
# 18469.0      1
# 29523.0      1
# 23641.0      1
# 22724.0      1
# 29906.0      1
# 30031.0      1

# %%
plot = grouped_agency_id.sort_values(by='id', ascending=False).plot.pie(y='id', figsize=(15, 15))

# %% [markdown]
# Ok, it's clear that a bit more then 3/4 of agency data belongs two big agencies. Rest of about 1/4 are for all other's

# %% [markdown]
# #### Visualise Min/Avg/Max square meters distribution
# <hr>

# %%
aggregate = pd.DataFrame(columns=['rooms_count', 'total_square_meters_min', 'total_square_meters_avg', 'total_square_meters_max'])

# %%
temp = df[['rooms_count', 'total_square_meters']]
total_square_meters_min = temp.groupby("rooms_count").min()
total_square_meters_avg = temp.groupby("rooms_count").mean()
total_square_meters_max = temp.groupby("rooms_count").max()

total_square_meters_avg['total_square_meters'] = round(total_square_meters_avg['total_square_meters'], 1)

# %%
frames = [total_square_meters_min, total_square_meters_avg, total_square_meters_max]
aggregate = pd.concat(frames, axis=1)

# rename columns after concat
aggregate.columns = ['min', 'avg', 'max'] 
aggregate
# Out:
#                min    avg    max
# rooms_count
# 1             18.0   39.8  150.0
# 2             25.0   56.9  130.0
# 3             50.0   80.2  154.0
# 4             62.0  110.4  187.0
# 5             75.0  152.7  230.0
# 6            170.0  170.0  170.0

# %%
aggregate.plot(kind='bar', figsize=(15, 6))

plt.xlabel('# of rooms') 
plt.ylabel('Min/Avg/Max sqrt meters')
plt.title('Size distribution per # of rooms in appartments')

plt.show()

# %% [markdown]
# #### Visualise Min/Avg/Max prices distribution
# <hr>

# %%
aggregate = pd.DataFrame(columns=['rooms_count', 'price_min', 'price_avg', 'price_max'])

# %%
temp = df[['rooms_count', 'price_usd']]
p_min = temp.groupby("rooms_count").min()
p_avg = temp.groupby("rooms_count").mean()
p_max = temp.groupby("rooms_count").max()

p_avg['price_usd'] = round(p_avg['price_usd'], 1)

# %%
frames = [p_min, p_avg, p_max]
aggregate = pd.concat(frames, axis=1)

# rename columns after concat
aggregate.columns = ['min', 'avg', 'max'] 
aggregate
# Out:
#                 min     avg     max
# rooms_count
# 1             110.0   289.6  1200.0
# 2             110.0   336.8  1000.0
# 3             184.0   442.0  1800.0
# 4             294.0   783.6  1800.0
# 5             440.0   925.8  2000.0
# 6            1500.0  1500.0  1500.0

# %%
aggregate.plot(kind='bar', figsize=(15, 6))

plt.xlabel('# of rooms (size) of appartments') 
plt.ylabel('Min/Avg/Max price in usd')
plt.title('Price distribution per appartment size')

plt.show()

# %% [markdown]
# #### Maps Visualisation
# <hr>

# %%
def get_color(n):
    if n == 1:
        return "green"
    if n == 2:
        return "blue"
    if n == 3:
        return "yellow"
    if n == 4:
        return "black"
    if n == 5:
        return "white"

# %%
p = df[['id', 'longitude', 'latitude', 'rooms_count', 'price_uah']].query('longitude != "NaN" & latitude != "NaN"')
# create a Stamen Toner map of the world centered around Lviv, UA
lviv_map = folium.Map(location=[ 49.83, 24.05 ], zoom_start=11, tiles='OpenStreetMap')
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, id, num, price in zip(p.latitude, p.longitude, p.id, p.rooms_count, p.price_uah):
    folium.Marker(
        location = [lat, lng],
        popup = id, 
        tooltip = str(num) + " rooms<br>" + str(price) + " UAH",
        icon = folium.Icon(color=get_color(num))
    ).add_to(lviv_map)
# add incidents to map
lviv_map.add_child(incidents)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: color argument of Icon should be one of: {'cadetblue', 'orange', 'darkgreen', 'lightgray', 'black', 'green', 'darkred', 'lightred', 'gray', 'pink', 'blue', 'purple', 'lightblue', 'lightgreen', 'darkblue', 'red', 'white', 'beige', 'darkpurple'}.
#   if sys.path[0] == '':
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Uncovering insights

# %%
ds = df[['total_square_meters','rooms_count', 'price_usd']]
ds['roi'] = 100 * ds['total_square_meters']/ds['price_usd']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ds = ds.groupby('rooms_count').mean()
ds_mod = ds.apply(lambda x: round(x, 2))
ds_mod
# Out:
#              total_square_meters  price_usd    roi
# rooms_count
# 1                          39.77     289.57  14.31
# 2                          56.90     336.82  17.68
# 3                          80.20     442.05  19.90
# 4                         110.41     783.64  17.57
# 5                         152.69     925.85  19.00
# 6                         170.00    1500.00  11.33

# %% [markdown]
# ### Take away

# %% [markdown]
# * Vast majority of data - private sector, only a handful of records - commercial
# * Five Bedroom Apartments are on the verge of statistical error
# * Tree Bedroom Apartments preforms the best in ROI
# * One Bedroom Apartments are leading on the market, then Studio's, and then Two Bedrooms
